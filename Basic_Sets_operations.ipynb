# %%
# Basic Sets operations

s = {3,6,43,13,11,2,78,45,906,54,3,4}

# %%
print (s)
# Out:
# {2, 3, 4, 6, 906, 11, 43, 13, 78, 45, 54}

# %%
print (sorted(s))
# Out:
# [2, 3, 4, 6, 11, 13, 43, 45, 54, 78, 906]

# %%
print (sorted(s, reverse= True))
# Out:
# [906, 78, 54, 45, 43, 13, 11, 6, 4, 3, 2]

# %%
e = {3,55,23,78,21,46,98,71}
f = {1,90,46,55,32,40}

# %%
#Print the union of two sets
print ("Union", e|f)
# Out:
# Union {32, 1, 98, 3, 71, 40, 46, 78, 23, 21, 55, 90}

# %%
#Intersection of two sets
print("Intersection", e&f)
# Out:
# Intersection {46, 55}

# %%
#Difference of two sets
print ("Difference", e-f)
print ("Difference", f-e)
# Out:
# Difference {98, 3, 71, 78, 21, 23}
# Difference {32, 1, 40, 90}

# %%
s = {1,2,3,4,5}
s.add(78)
s
# Out:
# {1, 2, 3, 4, 5, 78}

# %%
s.update([12,28,37,46])
s
# Out:
# {1, 2, 3, 4, 5, 12, 28, 37, 46, 78}

# %%
s.discard(5)
s
# Out:
# {1, 2, 3, 4, 12, 28, 37, 46, 78}

# %%
s.discard(2)
s
# Out:
# {1, 3, 12, 28, 37, 46, 78}

# %%
s.clear()
s
# Out:
# set()
